# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas

# %%
data = pandas.read_csv('news2.csv')

# %%
new_data = pandas.DataFrame()
new_data['title_headlines']= data['title_headlines'].apply(lambda x: x[0:70])
# new_data['title_headlines']= data['title_headlines']

# %%
pandas.set_option('display.max_rows', None)
pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_colwidth', -1)  # more options can be specified also

# %%
# new_data

# %%
content_data = pandas.DataFrame()

content_data['content_news']= data['content_news'].dropna(axis=0).apply(lambda x: x[40:110])

# %%
content_data
# Out:
#                                                                   content_news
# 0    یا کیے جانے کے بعد کہ جمعرات کو خلیجِ عمان میں تیل کے دو ٹینکروں پر حم
# 9     جیل جا پہنچے ہیں جیل ان کے لیے نئی تو نہیں البتہ اس بار وہ 15 برس کی
# 10   ے تعلیمی وظیفے کی رقم نہ دینے کے باعث چین میں زیر تعلیم پاکستانی طلبا
# 11    بکر انٹرنیشنل ایوارڈ حاصل کرنے والی پہلی عرب مصنفہ بن گئی ہے۔ \nان کا
# 12   د انڈین بولر جسپریت بمرا کے ہاتھوں میں تھی۔\nآسٹریلیا کے بیٹسمین ڈیوڈ و
# 14    کی حکمران جماعت کنزرویٹو پارٹی کی قیادت سے مستعفی ہوگئی ہیں تاہم وہ ب
# 31   لوں میں پڑھنے والے بچوں کے والدین مقامی سکول انتظامیہ کے خلاف سراپا اح
# 32   ہاز کے ٹکر سے بال بال بچنے کے واقعے کے بعد دونوں ممالک ایک دوسرے کو اس
# 34   اد کو گولی مار کر ہلاک کر دیا گیا ہے اور نیم فوجی دستے سڑکوں پر گھوم ر
# 35   راہ نے انتباہ کیا ہے کہ دنیا میں ٹیکنالوجی کی دیو ہیکل کمپنیاں عالمی م
# 36   ی تقریب میں شہ بالے ترکش صدر رجب طیب اردوغان تھے۔ \nگزشتہ سال فٹبال ورل
# ...
